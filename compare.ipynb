# %% [markdown]
# <a href="https://colab.research.google.com/github/khatriprajwol/Data-Visualization-/blob/main/compare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Proposal

# %%
import requests
import pandas as pa
import seaborn as sns
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# ![PEyFuQw35Pr47sEvqyRyIqFuIcmbLLtzC6nJ9yGRnU8.png](data:image/png;base64,...)

# %% [markdown]
# ![596d0218c50c2997008b4e32.png](data:image/png;base64,...)

# %%
r = requests.get("https://en.wikipedia.org/wiki/Forbes%27_list_of_the_most_valuable_sports_teams")
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")   
len(html_soup.find_all('table'))
# Out:
# 15

# %%
tables = html_soup.find_all('table')
df = pa.read_html(str(tables))[0]
df
# Out:
#    Rank                   Team                 Sport          League  \
# 0    #1         Dallas Cowboys     American football             NFL
# 1    #2       New York Yankees              Baseball             MLB
# 2    #3        New York Knicks            Basketball             NBA
# 3    #4           FC Barcelona  Association football         La Liga
# 4    #5            Real Madrid  Association football         La Liga
# 5    #6  Golden State Warriors            Basketball             NBA
# 6    #7     Los Angeles Lakers            Basketball             NBA
# 7    #8   New England Patriots     American football             NFL
# 8    #9        New York Giants     American football             NFL
# 9   #10          Bayern Munich  Association football      Bundesliga
# 10  #11      Manchester United  Association football  Premier League
# 11  #12              Liverpool  Association football  Premier League
# 12  #13       Los Angeles Rams     American football             NFL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 50 non-null     object
#  1   Team                 50 non-null     object
#  2   Sport                50 non-null     object
#  3   League               50 non-null     object
#  4   Value (USD billion)  50 non-null     object
#  5   Growth (2016–20)     50 non-null     object
# dtypes: object(6)
# memory usage: 2.5+ KB

# %% [markdown]
# Here I tried to run **df.plot()** but it did not work. Now I know the reason why it was not working by looking at the data type. As you can see all my data types are object. In order to plot I must have some numeric value which I was missing in th firt place. So, I need to lot of cleaning in this table before I do anything.
