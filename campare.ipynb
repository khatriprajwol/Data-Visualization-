# %% [markdown]
# <a href="https://colab.research.google.com/github/khatriprajwol/Data-Visualization-/blob/main/campare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pa
import seaborn as sns
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# ![PEyFuQw35Pr47sEvqyRyIqFuIcmbLLtzC6nJ9yGRnU8.png](data:image/png;base64,...)

# %% [markdown]
# ![interactive-data-visualization-example-7.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![link]("https://site-cdn.givemesport.com/images/20/12/31/f571247c1faddf1d54119a6af839db11/690.jpg")

# %%
r = requests.get("")
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")
len(html_soup.find_all('table'))
# Out:
# 4

# %%
tables = html_soup.find_all('table')
df = pa.read_html(str(tables))[0]
df.head().T
# Out:
#                                                               0  \
# Position Pos                             1 Previous Position  1
# Club                                        Manchester City MCI
# Played Pl                                                    32
# Won W                                                        24
# Drawn D                                                       5
# Lost L                                                        3
# GF                                                           75
# GA                                                           20
# GD                                                          +55
# Points Pts                                                   77
# Form          W Sunday 6 March 2022 MCI 4 -1 MUN D Monday 14...
# Next               Watford Saturday 23 April 2022 MCI 15:00 WAT
# Unnamed: 12                                                 NaN
#
#                                                               1  \
# ...

# %%
ax= sns.scatterplot(data=df, x='Sport', y = 'Team',size="(USD billion)")
