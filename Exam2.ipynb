# %% [markdown]
# <a href="https://colab.research.google.com/github/khatriprajwol/Data-Visualization-/blob/main/Exam2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exam 2
# #Prajwol Khatri
# #CPSMA 4313

# %% [markdown]
# In this `Exam`, I will be working with the data from a fitbit provided on Kaggle. The link for the data can be found here,`https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv`. Also, in order to comlete this exam I have used resources from `google`, `github_repos` and several online genuine materials.

# %% [markdown]
# **https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv**
#
#
# -> **https://github.com/nurfnick/Data_Viz/blob/main/01_Python.ipynb**
#
#
# ->
# **https://www.geeksforgeeks.org/how-to-drop-one-or-multiple-columns-in-pandas-dataframe/**
#
#
# ->
# **https://github.com/nurfnick/Data_Viz/blob/main/18_One_Hot_Encoding.ipynb**
#
#
# ->
# **https://github.com/nurfnick/Data_Viz/blob/main/15_String_Cleaning.ipynb**
#
#
# ->
# **https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb**
#
# ->
# **https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb**
#
# ## I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course. ##

# %% [markdown]
# This exam includes how to handle data and data cleaning, followed by way to deal with datetime format, removing `-` or extra characters which are often unnecessary in the data.

# %%
import numpy as np #a matrix like package for handling data
import pandas as pd #a R like package for handling data
from scipy import stats #a way to just get a piece of a large package
import matplotlib.pyplot as plt #a way to generate plots, histograms, bar charts, and other types of charts 
import seaborn as sns #it is based on matplotlib
import requests #HTTP library
import pandas as pd # used to manipulate data and analyze it
from bs4 import BeautifulSoup #Used for a web scraping purposes to pull the data out of HTML and XML files
import re #Used for regular expression in Python.

# %% [markdown]
#   **`https://github.com/khatriprajwol/Data-Visualization-/blob/main/EXAM-1.ipynb`. I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
#
# All the libraries which I have used to complete exam are listed above. On the side of each library I have also mentioned a general idea of that particular library. I will not be using the `HTTP library`, `Beautiful Soup library` because I am dealing with `CSV` file. However, it would not be a problem to have it on hand.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv")
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# **`https://raw.githubusercontent.com/nurfnick/Data Viz/main/Activity Dataset V1.csv`. I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
#
#
#
# In the above code I have stored a data in a pandas data frame. The file I have used in this exam is `csv` file from `nurfnick` github repo. Here is the link : `https://raw.githubusercontent.com/nurfnick/Data Viz/main/Activity Dataset V1.csv`.
#
# As you can see here I would like to peak at my first few data that is why I have used `df.head()`. It just helps me to understand what kind of data I am dealing with.

# %%
df.tail()
# Out:
#      Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 995         995   2022-02-14   Pool Swimming      6.92   101       313
# 996         996   2022-02-14       Freestyle      9.48    61       219
# 997         997   2022-02-14       Freestyle      3.30    40       169
# 998         998   2022-02-14  Indoor Cycling      4.40    47        52
# 999         999   2022-02-14  Indoor Cycling      1.57   116       106
#
#      total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 995          NaN      28.66       173.30       234.73  ...      NaN      NaN
# 996          NaN       9.23       114.34       109.32  ...      NaN      NaN
# 997          NaN       7.37       133.97       122.96  ...      NaN      NaN
# 998          NaN      10.75       147.65       116.51  ...      NaN      NaN
# 999          NaN      25.37       143.41       182.80  ...      NaN      NaN
#
# ...

# %% [markdown]
# I think the first five data was not enough, but I am not interested in printing all data that because it takes memory space. Therefore, `df.tail()` command simply helps me to peak last five data in my data set. Which can be quickly used if we would like to look at our last five data.

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# activity_day       object
# workout_type       object
# distance          float64
# time                int64
# calories            int64
# total_steps       float64
# avg_speed         float64
# avg_cadence       float64
# max_cadence       float64
# avg_pace           object
# max_pace           object
# min_pace           object
# avg_heart_rate    float64
# max_heart_rate    float64
# min_heart_rate      int64
# vo2_max(%)          int64
# aerobic(%)          int64
# anaerobic(%)        int64
# intensive(%)        int64
# light(%)            int64
# dtype: object

# %% [markdown]
# As we see in the above result **df.dtypes** gave me data types where there are different data types some of them are `int64`, `object` and `float64`.
#
# The first data type is `Unnamed 0` which is assigned as an int64. I think it is appropriate to assign the serial number or `Unnamed 0` in this case a integer. It does not make sense if we change it to `float(1.2)` for a serial number.
#
# For the `activity_day` we can see it is an object type because it is in the date format which can not be treated as an int or float. Similarly, we have a `workout_type` which has at least one string that is why python interpreted it as an object type.
#
# I am really not sure what `International System of Unit` is used but in this case `distance` is a float which sounds reasonable to me. It will have a decimal values for `example 9.5 Km or 0.4 miles`.
#
# For the `time`, there is int data type we see an int because it is converted in seconds which often makes calculation easier.
#
# Also,`calories` is a int data type which is kind of true because in my personal experience I have never seen a label of `150.6` or `200.5` calores in a snickers bar.
#
# I am really not sure why `total_steps`, `avg_speed`, `avg_cadence`, `max_cadence`,`avg_heart_rate`, `max_heart_rate` has a float data type in this case. Is it because of NaN in the total_steps which is kind of odd. It should be object rather than float? Anyways, we can clean it which will not be a problem.
#
# Furthermore, `min_heart_rate` has a int data type. I do not think it is a right way to make it int data type because we already have avg_heart_rate and max_heart_rate as a float.
#
# Here, `vo2_max(%)`, `aerobic(%)`, `anaerobic(%)`, `intensive(%)`, `light(%)` all are treated as a int data type. However, I will not suggest to use percentage as a integer because, in real life we can not always get away with integer for a percentage. There will be a case where we have to deal with lot of decimal type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1000 non-null   int64
#  1   activity_day    1000 non-null   object
#  2   workout_type    1000 non-null   object
#  3   distance        1000 non-null   float64
#  4   time            1000 non-null   int64
#  5   calories        1000 non-null   int64
#  6   total_steps     554 non-null    float64
#  7   avg_speed       1000 non-null   float64
#  8   avg_cadence     1000 non-null   float64
#  9   max_cadence     1000 non-null   float64
#  10  avg_pace        554 non-null    object
#  11  max_pace        554 non-null    object
#  12  min_pace        554 non-null    object
#  13  avg_heart_rate  1000 non-null   float64
#  14  max_heart_rate  1000 non-null   float64
#  15  min_heart_rate  1000 non-null   int64
#  16  vo2_max(%)      1000 non-null   int64
# ...

# %% [markdown]
# Well, the above command is a different but do the same job which gives us information about the data types with **`Non-Null Count`** as a bonus.

# %% [markdown]
# This table needs some cleaning. So, we can see there are two repeated indexes which has a name `Unnamed: 0`.

# %%
df1 = pd.DataFrame(df)

for col in df1.columns:

    if 'Unnamed: 0' in col:

        del df1[col]

# %%
df1.head()
# Out:
#   activity_day    workout_type  distance  time  calories  total_steps  \
# 0   2022-01-01       Freestyle      9.30    77       123          NaN
# 1   2022-01-01       Freestyle      3.44    96        55          NaN
# 2   2022-01-01  Indoor Cycling      6.34    85        33          NaN
# 3   2022-01-01         Walking      7.91    42        82       1571.0
# 4   2022-01-01      Open Water      8.99    36       131          NaN
#
#    avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# 0      18.88       168.54       138.30      NaN      NaN      NaN
# 1      29.65       125.92       292.81      NaN      NaN      NaN
# 2      17.85        81.93       323.69      NaN      NaN      NaN
# 3      22.10        29.63       180.16    07:58    28:58    07:58
# 4      25.83        64.55       342.89      NaN      NaN      NaN
#
#    avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# **https://www.geeksforgeeks.org/how-to-drop-one-or-multiple-columns-in-pandas-dataframe/ . I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
# Here, I have used iterative way to remove that one partiular column. No doubt there are different ways. One alternative way that we were shown in the class is given below.

# %%
df.drop(['Unnamed: 0'], axis = 1)
# Out:
#     activity_day    workout_type  distance  time  calories  total_steps  \
# 0     2022-01-01       Freestyle      9.30    77       123          NaN
# 1     2022-01-01       Freestyle      3.44    96        55          NaN
# 2     2022-01-01  Indoor Cycling      6.34    85        33          NaN
# 3     2022-01-01         Walking      7.91    42        82       1571.0
# 4     2022-01-01      Open Water      8.99    36       131          NaN
# ..           ...             ...       ...   ...       ...          ...
# 995   2022-02-14   Pool Swimming      6.92   101       313          NaN
# 996   2022-02-14       Freestyle      9.48    61       219          NaN
# 997   2022-02-14       Freestyle      3.30    40       169          NaN
# 998   2022-02-14  Indoor Cycling      4.40    47        52          NaN
# 999   2022-02-14  Indoor Cycling      1.57   116       106          NaN
#
#      avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# ...

# %% [markdown]
# **`https://github.com/nurfnick/Data_Viz/blob/main/18_One_Hot_Encoding.ipynb`. I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
#
# We can also use `drop` command to delete that particular column from the data set. It do exactly the same as the previous one.

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %% [markdown]
# I have dropped the `Unnamed: 0` column. In order to apply the command we have to pass it through `df` so that it can update our `df` table.

# %%
df.head()
# Out:
#   activity_day    workout_type  distance  time  calories  total_steps  \
# 0   2022-01-01       Freestyle      9.30    77       123          NaN
# 1   2022-01-01       Freestyle      3.44    96        55          NaN
# 2   2022-01-01  Indoor Cycling      6.34    85        33          NaN
# 3   2022-01-01         Walking      7.91    42        82       1571.0
# 4   2022-01-01      Open Water      8.99    36       131          NaN
#
#    avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# 0      18.88       168.54       138.30      NaN      NaN      NaN
# 1      29.65       125.92       292.81      NaN      NaN      NaN
# 2      17.85        81.93       323.69      NaN      NaN      NaN
# 3      22.10        29.63       180.16    07:58    28:58    07:58
# 4      25.83        64.55       342.89      NaN      NaN      NaN
#
#    avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# Now we can clearly see that our `df` has now updated with our new indexes.

# %%
df.columns
# Out:
# Index(['activity_day', 'workout_type', 'distance', 'time', 'calories',
#        'total_steps', 'avg_speed', 'avg_cadence', 'max_cadence', 'avg_pace',
#        'max_pace', 'min_pace', 'avg_heart_rate', 'max_heart_rate',
#        'min_heart_rate', 'vo2_max(%)', 'aerobic(%)', 'anaerobic(%)',
#        'intensive(%)', 'light(%)'],
#       dtype='object')

# %% [markdown]
# We can always go back and look at the columns name. However, `df.columns` just saves us lot of time and makes our job easier. Here, we can see there are `_`, `()`, `%`. Let's clean `(%)` part from the column and any spaces between them.

# %%
cols = df.columns.map(lambda s: re.sub(r"[(.%)]","",s))
cols
# Out:
# Index(['activity_day', 'workout_type', 'distance', 'time', 'calories',
#        'total_steps', 'avg_speed', 'avg_cadence', 'max_cadence', 'avg_pace',
#        'max_pace', 'min_pace', 'avg_heart_rate', 'max_heart_rate',
#        'min_heart_rate', 'vo2_max', 'aerobic', 'anaerobic', 'intensive',
#        'light'],
#       dtype='object')

# %% [markdown]
# **`https://github.com/nurfnick/Data_Viz/blob/main/15_String_Cleaning.ipynb`. I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
#
# I have used `RegEx` package to remove **`number`**, **`%`** and **`_`**. It took me a while to do this but surprisingly I figured it out. At first I tried it without **`()`** which gave me a pain in my head. However, after putting the brackets it seems to be working.

# %%
df.columns = df.columns.map(lambda s: re.sub(r"[(.%)]","",s))

# %% [markdown]
# Now, I will apply this to my old table. In the below table now we can see the cleaned columns.

# %%
df.head()
# Out:
#   activity_day    workout_type  distance  time  calories  total_steps  \
# 0   2022-01-01       Freestyle      9.30    77       123          NaN
# 1   2022-01-01       Freestyle      3.44    96        55          NaN
# 2   2022-01-01  Indoor Cycling      6.34    85        33          NaN
# 3   2022-01-01         Walking      7.91    42        82       1571.0
# 4   2022-01-01      Open Water      8.99    36       131          NaN
#
#    avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# 0      18.88       168.54       138.30      NaN      NaN      NaN
# 1      29.65       125.92       292.81      NaN      NaN      NaN
# 2      17.85        81.93       323.69      NaN      NaN      NaN
# 3      22.10        29.63       180.16    07:58    28:58    07:58
# 4      25.83        64.55       342.89      NaN      NaN      NaN
#
#    avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max  aerobic  \
# 0           112.5           122.0             103       19       28
# ...

# %%
df.dtypes
# Out:
# activity_day       object
# workout_type       object
# distance          float64
# time                int64
# calories            int64
# total_steps       float64
# avg_speed         float64
# avg_cadence       float64
# max_cadence       float64
# avg_pace           object
# max_pace           object
# min_pace           object
# avg_heart_rate    float64
# max_heart_rate    float64
# min_heart_rate      int64
# vo2_max             int64
# aerobic             int64
# anaerobic           int64
# intensive           int64
# light               int64
# dtype: object

# %% [markdown]
# Here, the `activity_day` is an object. And we would like to convert it into **`datetime`** format.

# %%
pd.to_datetime(df.activity_day, format='%Y-%m-%d')
# Out:
# 0     2022-01-01
# 1     2022-01-01
# 2     2022-01-01
# 3     2022-01-01
# 4     2022-01-01
#          ...
# 995   2022-02-14
# 996   2022-02-14
# 997   2022-02-14
# 998   2022-02-14
# 999   2022-02-14
# Name: activity_day, Length: 1000, dtype: datetime64[ns]

# %% [markdown]
# **`https://github.com/nurfnick/Data_Viz/blob/main/16_Dates.ipynb`. I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
#
# In the above table it can be clearly seen that the datatype is an object and it has not been assigned as `datetime` yet. Therefore, I will give it the correct format. It is crucial to put right form of the date. In this case it is **`Year-month-day`**.

# %%
df.activity_day = pd.to_datetime(df.activity_day, format='%Y-%m-%d')

# %% [markdown]
# I am applying the changes into my `df`. We should not forget to do this part otherwise, it won't change the datatype for us.

# %%
df.dtypes
# Out:
# activity_day      datetime64[ns]
# workout_type              object
# distance                 float64
# time                       int64
# calories                   int64
# total_steps              float64
# avg_speed                float64
# avg_cadence              float64
# max_cadence              float64
# avg_pace                  object
# max_pace                  object
# min_pace                  object
# avg_heart_rate           float64
# max_heart_rate           float64
# min_heart_rate             int64
# vo2_max                    int64
# aerobic                    int64
# anaerobic                  int64
# intensive                  int64
# light                      int64
# dtype: object

# %% [markdown]
# Compared to above table we can see that `activity_day` now has been `changed` to `datetime` format datatype.

# %% [markdown]
# In my table there ara NaN for `total_steps`. Therefore, I am going to give it an appropriate numbe of steps. In order to do that I need `fillna`.

# %%
df.total_steps.fillna(0)
# Out:
# 0         0.0
# 1         0.0
# 2         0.0
# 3      1571.0
# 4         0.0
#         ...
# 995       0.0
# 996       0.0
# 997       0.0
# 998       0.0
# 999       0.0
# Name: total_steps, Length: 1000, dtype: float64

# %% [markdown]
# **`https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb.` I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
#
# All the `NaN` is now filled with `0's`. Before it's data type was `float` however, `NaN` string was there. So, it was not provided its `right datatype`.

# %%
df.total_steps = df.total_steps.fillna(0)

# %% [markdown]
# I am applying it back to my table.

# %%
df.head()
# Out:
#   activity_day    workout_type  distance  time  calories  total_steps  \
# 0   2022-01-01       Freestyle      9.30    77       123          0.0
# 1   2022-01-01       Freestyle      3.44    96        55          0.0
# 2   2022-01-01  Indoor Cycling      6.34    85        33          0.0
# 3   2022-01-01         Walking      7.91    42        82       1571.0
# 4   2022-01-01      Open Water      8.99    36       131          0.0
#
#    avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# 0      18.88       168.54       138.30      NaN      NaN      NaN
# 1      29.65       125.92       292.81      NaN      NaN      NaN
# 2      17.85        81.93       323.69      NaN      NaN      NaN
# 3      22.10        29.63       180.16    07:58    28:58    07:58
# 4      25.83        64.55       342.89      NaN      NaN      NaN
#
#    avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max  aerobic  \
# 0           112.5           122.0             103       19       28
# ...

# %% [markdown]
# Now, my `table` looks more `cleaned` than it was `before`.

# %%
df.avg_pace = df.avg_pace.fillna(0)

# %%
df.head()
# Out:
#   activity_day    workout_type  distance  time  calories  total_steps  \
# 0   2022-01-01       Freestyle      9.30    77       123          0.0
# 1   2022-01-01       Freestyle      3.44    96        55          0.0
# 2   2022-01-01  Indoor Cycling      6.34    85        33          0.0
# 3   2022-01-01         Walking      7.91    42        82       1571.0
# 4   2022-01-01      Open Water      8.99    36       131          0.0
#
#    avg_speed  avg_cadence  max_cadence avg_pace max_pace min_pace  \
# 0      18.88       168.54       138.30        0      NaN      NaN
# 1      29.65       125.92       292.81        0      NaN      NaN
# 2      17.85        81.93       323.69        0      NaN      NaN
# 3      22.10        29.63       180.16    07:58    28:58    07:58
# 4      25.83        64.55       342.89        0      NaN      NaN
#
#    avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max  aerobic  \
# 0           112.5           122.0             103       19       28
# ...

# %%
df.avg_pace = df['avg_pace'].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   activity_day    1000 non-null   datetime64[ns]
#  1   workout_type    1000 non-null   object
#  2   distance        1000 non-null   float64
#  3   time            1000 non-null   int64
#  4   calories        1000 non-null   int64
#  5   total_steps     1000 non-null   float64
#  6   avg_speed       1000 non-null   float64
#  7   avg_cadence     1000 non-null   float64
#  8   max_cadence     1000 non-null   float64
#  9   avg_pace        1000 non-null   datetime64[ns]
#  10  max_pace        554 non-null    object
#  11  min_pace        554 non-null    object
#  12  avg_heart_rate  1000 non-null   float64
#  13  max_heart_rate  1000 non-null   float64
#  14  min_heart_rate  1000 non-null   int64
#  15  vo2_max         1000 non-null   int64
# ...

# %% [markdown]
# We can see now my data avg_pace is changed to datetime format.

# %%
df['avg_pace'] = pd.DatetimeIndex(df['avg_pace'])
df['avg_pace'] = df['avg_pace'].apply(lambda avg_pace: avg_pace.hour + (avg_pace.minute / 60))
df.T
# Out:
#                                 0                    1                    2    \
# activity_day    2022-01-01 00:00:00  2022-01-01 00:00:00  2022-01-01 00:00:00
# workout_type              Freestyle            Freestyle       Indoor Cycling
# distance                        9.3                 3.44                 6.34
# time                             77                   96                   85
# calories                        123                   55                   33
# total_steps                     0.0                  0.0                  0.0
# avg_speed                     18.88                29.65                17.85
# avg_cadence                  168.54               125.92                81.93
# max_cadence                   138.3               292.81               323.69
# avg_pace                        0.0                  0.0                  0.0
# max_pace                        NaN                  NaN                  NaN
# ...

# %% [markdown]
# **`https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#id28`. I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
# Here, I have used datetimeindex to change object data type to the float. Since we know that there  is 60 min in 1 hrs. Our time is given in hour and minute. I used simple mathematics to change my hour to minute by diving it by 60.

# %%
df.groupby('workout_type').calories.agg(['mean','median','count','std'])
# Out:
#                        mean  median  count         std
# workout_type
# Cricket          307.548387   330.0     93  149.950609
# Freestyle        278.552083   294.0     96  163.703768
# Indoor Cycling   280.450000   306.0     80  156.633322
# Open Water       296.747253   328.0     91  160.068499
# Outdoor Cycling  299.129412   301.0     85  158.731263
# Outdoor Running  301.469136   349.0     81  165.725080
# Pool Swimming    283.414894   300.0     94  157.576703
# Trail Run        267.966667   264.0     90  155.748533
# Treadmill        278.142857   269.5     98  146.963352
# Trekking         283.127660   280.5     94  151.034870
# Walking          276.040816   270.5     98  157.287570

# %% [markdown]
# **https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb. I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
#
# I have done `groupby` function followed by `agg` which can be used to calculate `mean`, `median`, `count`, and `standard deviation` in a table form just like the above table.

# %%
aer = df.aerobic > 30
pd.concat([df,pd.DataFrame({'Thirty':aer})], axis = 1)
# Out:
#     activity_day    workout_type  distance  time  calories  total_steps  \
# 0     2022-01-01       Freestyle      9.30    77       123          0.0
# 1     2022-01-01       Freestyle      3.44    96        55          0.0
# 2     2022-01-01  Indoor Cycling      6.34    85        33          0.0
# 3     2022-01-01         Walking      7.91    42        82       1571.0
# 4     2022-01-01      Open Water      8.99    36       131          0.0
# ..           ...             ...       ...   ...       ...          ...
# 995   2022-02-14   Pool Swimming      6.92   101       313          0.0
# 996   2022-02-14       Freestyle      9.48    61       219          0.0
# 997   2022-02-14       Freestyle      3.30    40       169          0.0
# 998   2022-02-14  Indoor Cycling      4.40    47        52          0.0
# 999   2022-02-14  Indoor Cycling      1.57   116       106          0.0
#
#      avg_speed  avg_cadence  max_cadence  avg_pace  ... min_pace  \
# ...

# %% [markdown]
# **`https://github.com/nurfnick/Data_Viz/blob/main/20_Cleaning_Conclusion.ipynb.` I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.**
#
#
# I am trying to find here if an aerobic activity is greater than thirty percent. And we can see the results in above table.

# %%
df.activity_day.unique()
# Out:
# array(['2022-01-01T00:00:00.000000000', '2022-01-02T00:00:00.000000000',
#        '2022-01-03T00:00:00.000000000', '2022-01-04T00:00:00.000000000',
#        '2022-01-05T00:00:00.000000000', '2022-01-06T00:00:00.000000000',
#        '2022-01-07T00:00:00.000000000', '2022-01-08T00:00:00.000000000',
#        '2022-01-09T00:00:00.000000000', '2022-01-10T00:00:00.000000000',
#        '2022-01-11T00:00:00.000000000', '2022-01-12T00:00:00.000000000',
#        '2022-01-13T00:00:00.000000000', '2022-01-14T00:00:00.000000000',
#        '2022-01-15T00:00:00.000000000', '2022-01-16T00:00:00.000000000',
#        '2022-01-17T00:00:00.000000000', '2022-01-18T00:00:00.000000000',
#        '2022-01-19T00:00:00.000000000', '2022-01-20T00:00:00.000000000',
#        '2022-01-21T00:00:00.000000000', '2022-01-22T00:00:00.000000000',
#        '2022-01-23T00:00:00.000000000', '2022-01-24T00:00:00.000000000',
#        '2022-01-25T00:00:00.000000000', '2022-01-26T00:00:00.000000000',
# ...

# %%
df.groupby('workout_type').agg('max_cadence')

# %% [markdown]
# I could not figure it out.

# %%
#df[(df.activity_day == 'day.')&(df.max_cadence == 'max')]

# %% [markdown]
# It took me about almost a whole day to work on this exam. However, the questions were not that hard and many of them were straight forward.

# %% [markdown]
# I felt that question `1f`, `1g`, `1h`, `1i` was harder than other problems. I could not figure it out for a long time. I have tried to convert object type to `datetime` format but unfortunately it was not working. And the easiest part was loading data, removing spaces, percentage part.

# %% [markdown]
# I believe we should have spend more time doing date and time format. Because in my personal experience time series data is hard to visualize. One of the interesting part we have done in the class was cleaning mispelled columns extra spaces. Doing different ways in data cleaning I have realized that there are more things that I need to learn.
