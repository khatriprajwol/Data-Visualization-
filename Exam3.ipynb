# %% [markdown]
# <a href="https://colab.research.google.com/github/khatriprajwol/Data-Visualization-/blob/main/Exam3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Exam 3
# ##Prajwol Khatri
# ##CPSMA 4313

# %% [markdown]
# ##Introduction
#
# In this project I will be working with a data from the 2018 World Cup that is provided in Kaggle github repo from [nufnick](https://raw.githubusercontent.com/nurfnick/Data_Viz/main/worldCupPlayer.csv). I have used several visualization techniques to analyze data from 2018 World Cup. The data provided to me was already clean and ready-to-go. All the sources I have used are listed below with a link from the original source. Also, I have used online resources from `google` and `github_repos` from the data visualization class. All the resources are listed below beneath each code as well. The libraries that I have used are `*pandas*`, `*seaborn*`, `*matplotlib*`.

# %% [markdown]
# ###LINKS USED ARE LISTED BELOWS:
#
# **`https://raw.githubusercontent.com/nurfnick/Data_Viz/main/worldCupPlayer.csv`**
#
# **`https://github.com/khatriprajwol/Data-Visualization-/blob/main/Many%20Distribution.ipynb`**
#
# **`https://github.com/khatriprajwol/Data-Visualization-/blob/main/Histogram.ipynb`**
#
# **`https://github.com/khatriprajwol/Data-Visualization-/blob/main/Histogram.ipynb`**
#
# **`https://github.com/nurfnick/Data_Viz/blob/main/27_Proportions.ipynb`**
#
# **`https://github.com/khatriprajwol/Data-Visualization-/blob/main/Many%20Distribution.ipynb`**
#
# **`https://www.tutorialspoint.com/how-to-create-a-stacked-bar-chart-for-my-dataframe-using-seaborn-in-matplotlib#:~:text=To%20create%20a%20stacked%20bar%20chart%2C%20we%20can,and%20green%2C%20and%20label%20as%20count%20and%20select.`**
#
# **`https://github.com/nurfnick/Data_Viz/blob/main/28_Associations.ipynb`**
#
#
# I attest that the resources above were the only ones utilized in completing the exam and the work included is my own and no one else from the course.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/worldCupPlayer.csv")
df.head(30)
# Out:
#     Unnamed: 0  Rank               player                     club  age  \
# 0            0     1         Hakim Ziyech                     Ajax   25
# 1            2     2  Alireza Jahanbakhsh               AZ Alkmaar   24
# 2            4     3       Hirving Lozano            PSV Eindhoven   22
# 3            6    11         Lasse Schone                     Ajax   32
# 4           10    25       Santiago Arias            PSV Eindhoven   26
# 5           12    34      Karim El Ahmadi                Feyenoord   33
# 6           14   451      Karim El Ahmadi                Feyenoord   33
# 7           16   117       Tyronne Ebuehi             ADO Den Haag   22
# 8           18   146       Sofyan Amrabat                Feyenoord   21
# 9           20   299       Sofyan Amrabat                Feyenoord   21
# 10          22   160       Kasper Dolberg                     Ajax   20
# 11          24   205  Reza Ghoochannejhad            SC Heerenveen   30
# ...

# %% [markdown]
# I am importing the necessary Library that are pandas, seaborn and matplot. I have used **df.head(30)** because it prints 30 rows.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   603 non-null    int64
#  1   Rank         603 non-null    int64
#  2   player       603 non-null    object
#  3   club         603 non-null    object
#  4   age          603 non-null    int64
#  5   Apps         603 non-null    object
#  6   Mins         603 non-null    int64
#  7   Goals        603 non-null    int64
#  8   Assists      603 non-null    int64
#  9   Yel          603 non-null    int64
#  10  Red          603 non-null    int64
#  11  SpG          603 non-null    object
#  12  PS           603 non-null    float64
#  13  AerialsWon   603 non-null    object
#  14  MotM         603 non-null    int64
#  15  Rating       603 non-null    float64
#  16  nationality  603 non-null    object
# dtypes: float64(2), int64(9), object(6)
# memory usage: 80.2+ KB

# %% [markdown]
# The above table can be very handy when it comes to visualization. It provides us with the information of a data type we are going to be dealing with. That is why I have used **info()** command. Here, we can see some of the data are integers, some of them are objects and some of them are floats.

# %% [markdown]
# ![Manchester United](https://logodownload.org/wp-content/uploads/2016/10/manchester-united-logo-0.png)
#
#
#
# My favorite team is [**Manchester United**](https://www.manutd.com/) which is an english club. The table below shows the information about it. It is not doing pretty good these days but I still like it and I do follow it.

# %% [markdown]
# I am using **loc** function to show the information about my favorite club. Here you can see it is only showing the information about the Manchester United club.

# %%
df1 = df.loc[df["club"]=="Manchester United"]
df1
# Out:
#      Unnamed: 0  Rank           player               club  age    Apps  Mins  \
# 420         803     9       Paul Pogba  Manchester United   25   25(2)  2151
# 421         804   187       Paul Pogba  Manchester United   25    3(2)   279
# 426         813    17    Romelu Lukaku  Manchester United   25   33(1)  2869
# 427         815    16    Romelu Lukaku  Manchester United   25       8   704
# 434         828    27       Phil Jones  Manchester United   26      23  1975
# 435         830    28    Nemanja Matic  Manchester United   29   35(1)  3119
# 436         832    45    Nemanja Matic  Manchester United   29    6(1)   564
# 444         848    38     Ashley Young  Manchester United   32   28(2)  2448
# 445         850    51     Ashley Young  Manchester United   32       4   337
# 483         926   127    Jesse Lingard  Manchester United   25  20(13)  1823
# 484         928   426    Jesse Lingard  Manchester United   25    3(3)   246
# ...

# %% [markdown]
# I could also use **groupby** function as well.

# %%
by_nationality = df.groupby("club")
by_nationality.get_group("Manchester United")
# Out:
#      Unnamed: 0  Rank           player               club  age    Apps  Mins  \
# 420         803     9       Paul Pogba  Manchester United   25   25(2)  2151
# 421         804   187       Paul Pogba  Manchester United   25    3(2)   279
# 426         813    17    Romelu Lukaku  Manchester United   25   33(1)  2869
# 427         815    16    Romelu Lukaku  Manchester United   25       8   704
# 434         828    27       Phil Jones  Manchester United   26      23  1975
# 435         830    28    Nemanja Matic  Manchester United   29   35(1)  3119
# 436         832    45    Nemanja Matic  Manchester United   29    6(1)   564
# 444         848    38     Ashley Young  Manchester United   32   28(2)  2448
# 445         850    51     Ashley Young  Manchester United   32       4   337
# 483         926   127    Jesse Lingard  Manchester United   25  20(13)  1823
# 484         928   426    Jesse Lingard  Manchester United   25    3(3)   246
# ...

# %% [markdown]
# There no difference in above table and below table. The only difference is the code used to call the table and group them together by **club** and club's name **Manchester United.**
#
#
#
#
# **https://github.com/khatriprajwol/Data-Visualization-/blob/main/Many%20Distribution.ipynb**

# %% [markdown]
# Now Ronaldo is in the Manchester United. Since, this data is from 2018 I would like to know information about him.

# %%
by_nationality = df.groupby("player")
by_nationality.get_group("Cristiano Ronaldo")
# Out:
#      Unnamed: 0  Rank             player         club  age Apps  Mins  Goals  \
# 196         383     2  Cristiano Ronaldo  Real Madrid   33   27  2293     26
# 197         384     4  Cristiano Ronaldo  Real Madrid   33   13  1170     15
#
#      Assists  Yel  Red  SpG    PS AerialsWon  MotM  Rating nationality
# 196        5    1    0  6.6  81.6        1.3     7    7.94    Portugal
# 197        3    2    0  6.3  81.4        1.7     4    8.12    Portugal

# %% [markdown]
# From the table above, I can see the top rated player is **Paul Pogba** who is in the 9th rank. There are other players who are from **England** like **Marcus Rashford**. Here the table includes many information such as number of yellow cards and red cards shown to the player. For example Pogba was shown one red card but Rashford has none.

# %%
df.hist()
plt.show()

# %% [markdown]
# As we can see how messy above graph is. I can not get any information from it. It shows me the histogram about the **Goals**. However, I would like to look particular in the **Goals.**

# %%
#ax = plt.hist(df.Goals, bins = 15, density = True, histtype='bar', align= 'mid' , orientation ='vertical',rwidth = 5 ,log = False, color = None, Label = [7]) could not put the title
ax = sns.histplot(data = df, x = 'Goals', y= None)
ax.set_title("Distribution of Goals")
plt.show()

# %% [markdown]
# As we can see it is clear and easy to understand this histogram. Histogram helps us to understand the distribution of a data over a continuous interval. It is showing a numeric data in a range. From the above graph we can tell it is right-skewed distribution. It is true that it is not that easy to score too many goals. Players not scoring is higher than player who score 20 goals.
#
#
# **`https://github.com/khatriprajwol/Data-Visualization-/blob/main/Histogram.ipynb`**

# %%
ax = sns.histplot(data = df, x = 'Goals', y= None, hue='nationality', )
ax.set_title("Distribution of Goals by nationality")
plt.show()

# %% [markdown]
# This histogram shows the goal distribution by nationality.

# %%
df.groupby('Assists').Goals.plot.hist(alpha = .9, bins =10, xlim = [0,20],legend = True, title = "Distribution of Goals and Assists")
plt.show()

# %% [markdown]
# Not the graph that I have expected. Since I have passed df as a data frame which gave me the distribution of all data. It is hard to read any information.
#
# I will try to make a grpah of **Goals** and **Assists** of my favorite club. [link](**`https://github.com/khatriprajwol/Data-Visualization-/blob/main/Histogram.ipynb`**)

# %%
df1.groupby('Assists').Goals.plot.hist(alpha = .9, bins =5, xlim = [0,20],legend = True, title = "Bad Graph")
plt.show()

# %%
plt.rcParams["figure.figsize"] = [7, 7]
plt.rcParams["figure.autolayout"] = True
bar_plot1 = sns.histplot(x='Goals', y= None, data=df, label="Goals", color="red")
bar_plot2 = sns.histplot(x='Assists', y=None, data=df, label="Assists", color="green")
plt.legend(ncol=2, loc="lower right", frameon=True, title = 'Distribution of Goals and Assists')
plt.show()

# %% [markdown]
# I think this is little clear. Here, they are not over lapped with each other because two things are different. We can tell that the goals and assists are in the same height. A good assists can led to a goal? [link](**`https://www.tutorialspoint.com/how-to-create-a-stacked-bar-chart-for-my-dataframe-using-seaborn-in-matplotlib#:~:text=To%20create%20a%20stacked%20bar%20chart%2C%20we%20can,and%20green%2C%20and%20label%20as%20count%20and%20select.`**)

# %%
ax = sns.barplot(data = df,y = 'Goals', x = 'nationality',)
ax.set_title('Goals and natonality')
ax.set_ylabel('Goals')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %% [markdown]
# From the data we can see Egypt scored the highest goal.
#
#
# **`https://github.com/nurfnick/Data_Viz/blob/main/27_Proportions.ipynb`**

# %%
ax = sns.barplot(data = df1, y = 'Goals', x = 'nationality')
ax.set_title('Goals and natonality')
ax.set_ylabel('Goals')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %% [markdown]
# No way I will go forward without knowing my favorite team statistics. And again this is of my favorite club's data. At that time Lukaku was the highest scorer among the other players.

# %%
ax = sns.barplot(data = df1, y = 'Goals', x = 'nationality', ci= None)
ax.set_title('Goals and natonality')
ax.set_ylabel('Goals')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.show()

# %% [markdown]
# Here I would like to point out one thing. There is a black line in the one of the above graph but not the above graph. So, these are the error bars. It represents the uncertainity or it is a confidence interval by default it is set 95%.

# %%
df.boxplot(column = 'Yel',by = 'nationality',rot = 90, layout= None)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# The above data shows the box plot of **Yellow Card** and **nationality**. A box plot gives us a basic idea of the distribution of the data. IF the box plot is relatively short, then the data is more compact. If the box plot is relatively tall, then the data is spread out. Here, our data is compact it is not that spread out. There are some outliers in most of the data which we can see in the graph. It is a large data so the outliers are expected. **Tunisia** got lot of yellow cards than other countries.

# %%
ax = sns.boxplot(data = df, x = 'nationality', y = 'Yel')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
ax.set_title('Yellow Card and natonality')
plt.show()

# %% [markdown]
# I have used seaborn to so the box-plot. Above two graphs are same but the way I did is different. I found easier to use seaborn.
#
#
# **`https://github.com/khatriprajwol/Data-Visualization-/blob/main/Many%20Distribution.ipynb`**

# %%
ax = sns.boxplot(data = df1, x = 'nationality', y = 'Yel',hue="age")
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
ax.set_title('Manchester United Yellow Card and natonality')
plt.show()

# %% [markdown]
# I wanted to know about the club too that is why I was peeking the data about it.  **Young** from **England 🏴󠁧󠁢󠁥󠁮󠁧󠁿**  recived more yellow cards average of 4 and **Pogba** from **France 🇫🇷**  received average of 3.5. We can see it in the above table as well that Young got 7 and pogba got 5.

# %%
ax = sns.boxplot(data = df1, x = 'nationality', y = 'Red')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
ax.set_title('Manchester United Red Card by natonality')
plt.show()

# %% [markdown]
# It looks like **Pogba** from **France🇫🇷** was the only person who got red card.

# %%
ax=sns.scatterplot(data = df, y = 'Goals', x = 'Assists', hue = (df["club"]=="Manchester United"))
ax.set_title('Manchester United Goals and Assists')
plt.show()

# %% [markdown]
# In the above graph I have made scatter plot of *Manchester United Goals and Assist*. In the above graph the orange dots are the one with **Manchester United**. Here we can see association among the variables. I have used **hue** function to label my favorite club in the graph. We can see outliers clearly. Goals and Assests possess strong relationship. Some of the goals are scored with out assists.

# %%
df2 = df.loc[df["nationality"]=="France"]
df2
# Out:
#      Unnamed: 0  Rank             player                 club  age   Apps  \
# 30           59     5  Antoine Griezmann      Atletico Madrid   27   7(1)
# 31           60    13  Antoine Griezmann      Atletico Madrid   27  30(2)
# 32           62   140  Antoine Griezmann      Atletico Madrid   27      6
# 33           64     8        Nabil Fekir                 Lyon   24      8
# 34           65     3        Nabil Fekir                 Lyon   24  28(2)
# 68          131    93     Olivier Giroud              Arsenal   31      6
# 91          177   156    Lucas Hernandez      Atletico Madrid   22   7(1)
# 92          179    17    Lucas Hernandez      Atletico Madrid   22  24(3)
# 106         206   183    Florian Thauvin            Marseille   25   9(3)
# 107         208     2    Florian Thauvin            Marseille   25     35
# 111         215   197          Adil Rami            Marseille   32  13(1)
# 112         217    75          Adil Rami            Marseille   32     33
# ...

# %% [markdown]
# I am making another data frame that shows entire **France National Team**. All the players statistic is shown above.

# %%
plt.rcParams["figure.figsize"] = [7, 7]
plt.rcParams["figure.autolayout"] = True
bar_plot1 = sns.barplot(x='Goals', y='player', data=df2, label="Goals", color="red", ci= None)
bar_plot2 = sns.barplot(x='Assists', y='player', data=df2, label="Assists", color="green", ci= None)
plt.legend(ncol=2, loc="lower right", frameon=True, title= 'Goals and Assist according to the players')
plt.show()

# %% [markdown]
# The above graph shows the stacked bar chart of goals and assists. **Thomas Lemar** is a mid fielder no dbout he provide a assist and Thomas Lemar did not score a goal but he was the player who made most of the assists. **Florian** and **Nabir** scored most of the goals. From the graph I can say **Giround** scored only goals, no doubt he is the main striker of a team.
#
#
# **`https://www.tutorialspoint.com/how-to-create-a-stacked-bar-chart-for-my-dataframe-using-seaborn-in-matplotlib#:~:text=To%20create%20a%20stacked%20bar%20chart%2C%20we%20can,and%20green%2C%20and%20label%20as%20count%20and%20select.`**

# %%
ax= sns.heatmap(df.corr(), annot=True, linewidths=0.5,vmin = -1)
ax.set_title('Heat Map')
plt.show()

# %% [markdown]
# The above graph shows the **Heat Map** of all the data. Heat map is spread over in two dimensions. When it comes to large number of data heat map is the good choice. We can see different color code where some of them are darker and some of them are lighter. Some of the color are blue and some of the color are orange. Each square shows the correlation between the variables on each axis. Correlation ranges from -1 to +1. Values closer to zero means there is no linear trend between the two variables. The close to 1 the correlation is the more positively correlated they are; that is as one increases so does the other and the closer to 1 the stronger this relationship is. A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases. The diagonals are all light orange (1) because those squares are correlating each variable to itself. In this map it is a perfect correlation). For the rest the larger the number and darker the color the higher the correlation between the two variables. The plot is also symmetrical about the diagonal since the same two variables are being paired together in those squares.
#
#
# **`https://github.com/nurfnick/Data_Viz/blob/main/28_Associations.ipynb`**

# %% [markdown]
# It took me fairly a long time to work on the exam or even more. I started around 2 pm in the morning and ended up doing until 12 am at mid-night. It was indeed time consuming however, there were so many things which I have learned from this Exam. The more time I spend on it, it is fascinating me a lot.
#
# In my opinion this is a good review of what we have covered so far.
# I felt that the easiest part of this section is question number 1 which is about creating a data in pandas dataframe.
# I won't say the hardest but time consuming one for me was the stacked bar graph part. It took me couple of hours to do that part.
#
# I think this part is one of the best in our overall class which I have enjoyed doing. I found that Seaborn and matplot library are awesome. One of the visualization I am still unclear is violin plot. I could not understand what it is trying to say.
