# %% [markdown]
# <a href="https://colab.research.google.com/github/khatriprajwol/Data-Visualization-/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import matplotlib.pyplot as plt
import seaborn as sns 

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')

df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %%
ax = sns.scatterplot(data = df, 
                x = 'activity_day', 
                y = 'workout_type',
                hue = 'distance',
                hue_order ='time',
                size = 'calories',
                style_order='workout_type',
                x_bins= 10, y_bins= 10,
                legend='auto', n_boot=1000, alpha =1, x_jitter= None,
                ci= None
                )
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
g = sns.PairGrid(df, hue="distance")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-2394183c39a1> in <module>()
#       1 g = sns.PairGrid(df, hue="distance")
# ----> 2 g.map_diag(sns.histplot)
#       3 g.map_offdiag(sns.scatterplot)
#       4 g.add_legend()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1476             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1477             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1478             func(x=vector, **plot_kwargs)
#    1479             ax.legend_ = None
#    1480
#
# ...
